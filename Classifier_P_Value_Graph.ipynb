# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([0.16666667, 0.22222222, 0.27777778, 0.33333333, 0.38888889,
        0.44444444, 0.5       , 0.55555556, 0.61111111, 0.66666667,
        0.72222222, 0.77777778, 0.83333333])

y = np.array([  2,   5,  28,  69, 126, 197, 196, 163, 108,  65,  32,   5,   4])

# %%
fig, ax = plt.subplots()
ax.bar(x, y/1000, width=0.03)
ax.axvline(x=0.7, color = 'r')
ax.set_xlabel('Accuracy')
ax.set_ylabel('Frequency')
ax.text(0.725, 0.045, 'p = 0.041', style = 'italic', fontsize = 14)
# Out:
# Text(0.725, 0.045, 'p = 0.041')
